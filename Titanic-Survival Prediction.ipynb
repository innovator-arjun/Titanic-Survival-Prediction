# %%
import pandas as pd

# %%
tit_train=pd.read_csv('data/train.csv')
tit_test=pd.read_csv('data/test.csv')

# %%
tit_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
tit_train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                    Name   Sex  \
# count    891.000000  891.000000  891.000000                     891   891
# unique          NaN         NaN         NaN                     891     2
# top             NaN         NaN         NaN  Daly, Mr. Peter Denis   male
# freq            NaN         NaN         NaN                       1   577
# mean     446.000000    0.383838    2.308642                     NaN   NaN
# std      257.353842    0.486592    0.836071                     NaN   NaN
# min        1.000000    0.000000    1.000000                     NaN   NaN
# 25%      223.500000    0.000000    2.000000                     NaN   NaN
# 50%      446.000000    0.000000    3.000000                     NaN   NaN
# 75%      668.500000    1.000000    3.000000                     NaN   NaN
# max      891.000000    1.000000    3.000000                     NaN   NaN
#
#                Age       SibSp       Parch Ticket        Fare Cabin Embarked
# ...

# %%
tit_train.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
tit_train.Survived.value_counts().plot.bar(figsize=(5,3),title='Survival Count')
#0--> not survived
#1--> Survived

# %%
tit_train.Pclass.value_counts().plot.bar(figsize=(6,3),title='Ticket class')

# %%
tit_train.Sex.value_counts().plot.bar()

# %%
tit_train.sample(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 801          802         1       2
# 634          635         0       3
# 236          237         0       2
# 327          328         1       2
# 846          847         0       3
# 885          886         0       3
# 49            50         0       3
# 884          885         0       3
# 856          857         1       1
# 426          427         1       2
# 84            85         1       2
# 376          377         1       3
# 510          511         1       3
# 445          446         1       1
# 588          589         0       3
# 257          258         1       1
# 32            33         1       3
# 203          204         0       3
# 247          248         1       2
# 58            59         1       2
#
#                                               Name     Sex   Age  SibSp  \
# 801    Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.0      1
# ...

# %%
null_counts=tit_train.isnull().sum()
null_counts[null_counts>0].sort_values(ascending=True)
# Out:
# Embarked      2
# Age         177
# Cabin       687
# dtype: int64

# %%
print(tit_train.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
tit_train.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
import seaborn as sns
sns.barplot(x='Sex',y='Survived',data=tit_train)

print("Percentage of females who survived:", tit_train["Survived"][tit_train["Sex"] == 'female'].value_counts(normalize = True)[1]*100)


print("Percentage of Male who survived:", tit_train["Survived"][tit_train["Sex"] == 'male'].value_counts(normalize = True)[1]*100)
# Out:
# Percentage of females who survived: 74.20382165605095
# Percentage of Male who survived: 18.890814558058924

# %%
tit_train.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
sns.barplot(x='Pclass',y='Survived',data=tit_train)

print('Survived 1st class',tit_train['Survived'][tit_train['Pclass']==1].value_counts(normalize=True)[1]*100)
print('Survived 2nd Class',tit_train['Survived'][tit_train['Pclass']==2].value_counts(normalize=True)[1]*100)
print('Survived 3rd Class',tit_train['Survived'][tit_train['Pclass']==3].value_counts(normalize=True)[1]*100)
# Out:
# Survived 1st class 62.96296296296296
# Survived 2nd Class 47.28260869565217
# Survived 3rd Class 24.236252545824847

# %%
sns.barplot(x='SibSp',y='Survived',data=tit_train)

print('% of SibSp 0 :',tit_train['Survived'][tit_train['SibSp']==0].value_counts(normalize=True)[1]*100)

print('% of SibSp 1 :',tit_train['Survived'][tit_train['SibSp']==1].value_counts(normalize=True)[1]*100)

print('% of SibSp 2:',tit_train['Survived'][tit_train['SibSp']==2].value_counts(normalize=True)[1]*100)


print('% of SibSp 3:',tit_train['Survived'][tit_train['SibSp']==3].value_counts(normalize=True)[1]*100)
# Out:
# % of SibSp 0 : 34.53947368421053
# % of SibSp 1 : 53.588516746411486
# % of SibSp 2: 46.42857142857143
# % of SibSp 3: 25.0

# %%
tit_train.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
tit_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
tit_train.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
sns.barplot(x='Parch',y='Survived',data=tit_train)

# %%
import numpy as np

# %%
tit_train['Age']=tit_train['Age'].fillna(-0.5)
tit_test['Age']=tit_test['Age'].fillna(-0.5)

bins=[-1,0,5,12,18,24,35,60,np.inf]

labels=['Unknown','Baby','Child','Teenager','Student','Young Adult','Adult','Senior']

tit_train['AgeGroup']=pd.cut(tit_train['Age'],bins,labels=labels)

tit_test['AgeGroup']=pd.cut(tit_test['Age'],bins,labels=labels)

# %%
sns.barplot(x='Survived',y='AgeGroup',data=tit_train)

# %%
tit_train.Cabin.value_counts()
# Out:
# G6             4
# B96 B98        4
# C23 C25 C27    4
# C22 C26        3
# D              3
# F2             3
# F33            3
# E101           3
# C93            2
# E121           2
# C124           2
# B20            2
# C83            2
# C65            2
# E33            2
# D33            2
# B28            2
# B5             2
# C78            2
# D17            2
# C52            2
# C126           2
# C123           2
# B51 B53 B55    2
# D35            2
# E67            2
# F4             2
# B35            2
# E24            2
# B18            2
#               ..
# D28            1
# C118           1
# D15            1
# T              1
# A19            1
# F G63          1
# A14            1
# D9             1
# E46            1
# C50            1
# C128           1
# C7             1
# B101           1
# C32            1
# B42            1
# C46            1
# B50            1
# C86            1
# F38            1
# C99            1
# B79            1
# ...

# %%
tit_train['CabinBool']=tit_train['Cabin'].notnull().astype('int')
tit_test['CabinBool']=tit_test['Cabin'].notnull().astype('int')

sns.barplot(x='CabinBool',y='Survived',data=tit_train)

# %%
tit_train.CabinBool.value_counts()
# Out:
# 0    687
# 1    204
# Name: CabinBool, dtype: int64

# %%
tit_test.describe(include='all')
# Out:
#         PassengerId      Pclass                         Name   Sex  \
# count    418.000000  418.000000                          418   418
# unique          NaN         NaN                          418     2
# top             NaN         NaN  Ryerson, Master. John Borie  male
# freq            NaN         NaN                            1   266
# mean    1100.500000    2.265550                          NaN   NaN
# std      120.810458    0.841838                          NaN   NaN
# min      892.000000    1.000000                          NaN   NaN
# 25%      996.250000    1.000000                          NaN   NaN
# 50%     1100.500000    3.000000                          NaN   NaN
# 75%     1204.750000    3.000000                          NaN   NaN
# max     1309.000000    3.000000                          NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare  \
# count   418.000000  418.000000  418.000000       418  417.000000
# ...

# %%
tit_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked     AgeGroup  CabinBool
# 0      0         A/5 21171   7.2500   NaN        S      Student          0
# 1      0          PC 17599  71.2833   C85        C        Adult          1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Young Adult          0
# ...

# %%
tit_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked     AgeGroup  CabinBool
# 0  34.5      0      0   330911   7.8292   NaN        Q  Young Adult          0
# 1  47.0      1      0   363272   7.0000   NaN        S        Adult          0
# 2  62.0      0      0   240276   9.6875   NaN        Q       Senior          0
# 3  27.0      0      0   315154   8.6625   NaN        S  Young Adult          0
# 4  22.0      1      1  3101298  12.2875   NaN        S      Student          0

# %%
test_null_count=tit_test.isnull().sum()
test_null_count[test_null_count>0].sort_values(ascending=True)
# Out:
# Fare       1
# Cabin    327
# dtype: int64

# %%
tit_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked     AgeGroup  CabinBool
# 0  34.5      0      0   330911   7.8292   NaN        Q  Young Adult          0
# 1  47.0      1      0   363272   7.0000   NaN        S        Adult          0
# 2  62.0      0      0   240276   9.6875   NaN        Q       Senior          0
# 3  27.0      0      0   315154   8.6625   NaN        S  Young Adult          0
# 4  22.0      1      1  3101298  12.2875   NaN        S      Student          0

# %%
combine=[tit_train,tit_test]

# %%
for dataset in combine:
    dataset['Title']=dataset.Name.str.extract(' ([A-Za-z]+)\.',expand=False)

# %%
pd.crosstab(tit_train['Title'],tit_train['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for dataset in combine:
    dataset['Title']=dataset['Title'].replace(['Lady','Capt','Col','Don','Dr','Major',
                                              'Rev','Jonkheer','Dona'],'Rare')
    
    dataset['Title']=dataset['Title'].replace(['Countess','Lady','Sir'],'Royal')
    
    dataset['Title']=dataset['Title'].replace(['Mlle','Ms'],'Miss')
    
    dataset['Title']=dataset['Title'].replace('Mme','Mrs')

# %%
tit_train[['Title','Survived']].groupby(['Title'],as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4    Rare  0.285714
# 5   Royal  1.000000
