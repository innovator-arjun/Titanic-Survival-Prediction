# %%
import pandas as pd

# %%
tit_train=pd.read_csv('data/train.csv')
tit_test=pd.read_csv('data/test.csv')

# %%
tit_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
tit_train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                   Name   Sex  \
# count    891.000000  891.000000  891.000000                    891   891
# unique          NaN         NaN         NaN                    891     2
# top             NaN         NaN         NaN  Maioni, Miss. Roberta  male
# freq            NaN         NaN         NaN                      1   577
# mean     446.000000    0.383838    2.308642                    NaN   NaN
# std      257.353842    0.486592    0.836071                    NaN   NaN
# min        1.000000    0.000000    1.000000                    NaN   NaN
# 25%      223.500000    0.000000    2.000000                    NaN   NaN
# 50%      446.000000    0.000000    3.000000                    NaN   NaN
# 75%      668.500000    1.000000    3.000000                    NaN   NaN
# max      891.000000    1.000000    3.000000                    NaN   NaN
#
#                Age       SibSp       Parch Ticket        Fare    Cabin  \
# ...

# %%
tit_train.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
tit_train.Survived.value_counts().plot.bar(figsize=(5,3),title='Survival Count')
#0--> not survived
#1--> Survived

# %%
tit_train.Pclass.value_counts().plot.bar(figsize=(6,3),title='Ticket class')

# %%
tit_train.Sex.value_counts().plot.bar()

# %%
tit_train.sample(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 509          510         1       3
# 628          629         0       3
# 862          863         1       1
# 591          592         1       1
# 609          610         1       1
# 767          768         0       3
# 645          646         1       1
# 412          413         1       1
# 33            34         0       2
# 450          451         0       2
# 354          355         0       3
# 415          416         0       3
# 730          731         1       1
# 540          541         1       1
# 483          484         1       3
# 826          827         0       3
# 319          320         1       1
# 822          823         0       1
# 175          176         0       3
# 220          221         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 509                                     Lang, Mr. Fang    male  26.0      0
# ...

# %%
null_counts=tit_train.isnull().sum()
null_counts[null_counts>0].sort_values(ascending=True)
# Out:
# Embarked      2
# Age         177
# Cabin       687
# dtype: int64

# %%
print(tit_train.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
tit_train.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
import seaborn as sns
sns.barplot(x='Sex',y='Survived',data=tit_train)

print("Percentage of females who survived:", tit_train["Survived"][tit_train["Sex"] == 'female'].value_counts(normalize = True)[1]*100)


print("Percentage of Male who survived:", tit_train["Survived"][tit_train["Sex"] == 'male'].value_counts(normalize = True)[1]*100)
# Out:
# Percentage of females who survived: 74.20382165605095
# Percentage of Male who survived: 18.890814558058924
